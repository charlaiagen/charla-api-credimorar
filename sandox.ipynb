# %%
from pathlib import Path

from docling.backend.docling_parse_backend import DoclingParseDocumentBackend
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import(
    EasyOcrOptions,
    OcrMacOptions,
    PdfPipelineOptions,
    RapidOcrOptions,
    TesseractCliOcrOptions,
    TesseractOcrOptions
)
from docling.document_converter import DocumentConverter, PdfFormatOption

# %%
def main():
    input_doc = Path("data/BRADESCO_FORMULARIO_1.pdf")

    pipeline_options = PdfPipelineOptions()
    pipeline_options.do_ocr = True
    pipeline_options.do_table_structure = True
    pipeline_options.table_structure_options.do_cell_matching = True

    ocr_options = EasyOcrOptions(force_full_page_ocr=True)
    pipeline_options.ocr_options = ocr_options

    converter = DocumentConverter(
        format_options={
            InputFormat.PDF: PdfFormatOption(
                pipeline_options=pipeline_options
            )
        }
    )

    doc = converter.convert(input_doc).document
    md = doc.export_to_markdown()
    print(md)

# %%
if __name__ == '__main__':
    main()
# Out:
# <!-- image -->
#
# ## Proposta de Financiamento Imobiliário Comprador Pessoa Física
#
# ## Dados do 10 Comprador
#
# Nome Completo (sem abreviaçães)
#
# CPFIMF
#
# NAGYLA POLLYANNA FERREIRA CRUZ
#
# 926.064.231-00
#
# Profissão
#
# E-mail
#
# EMPRESÁRIA/AGRICULTURA
#
# nagyla\_pollyanna@hotmail com
#
# Estado Civil
#
# CASADA
#
# Campo obrigatório para quem não é casado. Vive em união estável?
#
# Sim
#
# Não
#
# É funcionário da Organização Bradesco ou parente de primeiro grau (pai ou filho)? Se sim informe código funcional:
#
# ## Dados do 20 Comprador
#
# Nome Completo (sem abreviaçães)
#
# CPFIMF 026.197.799-79
#
# EDER CARLOS MANDOTTI
#
# Profissão
#
# E-mail
#
# EMPRESÁRIO/AGRICULTOR
#
# eder mandotti@gmailcom
#
# Estado Civil
#
# CASADO
#
# Campo obrigatório para quem não é casado. Vive em união estável?
#
# Sim
#
# Não
#
# É funcionário da Organização Bradesco ou parente de primeiro grau (pai ou filho)? Se sim; informe código funcional:
#
# ## Dados do 30 Comprador
#
# Nome Completo (sem abreviaçães)
#
# CPFIMF
#
# Profissão
#
# E-mail
#
# Estado Civil
#
# Campo obrigatório para quem não é casado. Vive em união estável?
#
# Sim
#
# Não
#
# É funcionário da Organização Bradesco ou parente de primeiro grau (pai ou filho)? Se sim; informe código funcional:
#
# ## Dados do 40 Comprador
#
# Nome Completo (sem abreviaçães)
#
# CPFIMF
#
# Profissão
#
# E-mail
#
# Estado Civil
#
# Campo obrigatório para quem não é casado. Vive em união estável?
#
# Sim
#
# Não
#
# É funcionário da Organização Bradesco ou parente de primeiro grau (pai ou filho)? Se sim; informe código funcional:
#
# <!-- image -->
#
# ## Dados Bancários Pagamento das Prestaçães
#
# ## Autorizo 0 débito/ pagamento do valor das parcelas por meio de:
#
# Débito em conta corrente Bradesco abaixo indicada
#
# Boleto Bancário
#
# Para opção de pagamento das parcelas por meio débito em conta corrente, informar:
#
# Conta de titularidade do Comprador que autorizou 0 débito:
#
# Nome
#
# ## NAGYLA POLLYANNA FERREIRA CRUZ
#
# Agência Débito Parcela
#
# Conta Débito Parcela
#
# Dígito Conta
#
# 1066
#
# 2957
#
# 2
#
# Autorizo utilizar 0 limite de crédito; incluindo 0 Cheque Especial, se contratados; quando não houver saldo em conta;
#
# Autorizo 0 débito do valor da(s)   parcela(s)   vencida(s) inclusive de valor(es)   parcial(is) . (Os encargos serão incorporados nas parcelas seguintes; conforme detalhado em contrato)
#
# ## Dados do(s) 10 Vendedor(es) Pessoa Física/Pessoa Jurídica
#
# Nome Completo Razão Social (sem abreviaçães)
#
# CPFTCNP)IMF
#
# JOãO PIMENTA DA SILVA JUNIOR
#
# 029.176.851-23
#
# Profissão
#
# E-mail
#
# EMPRESÁRIO
#
# joaopimenta@outlook com br
#
# Estado Civil
#
# SOLTEIRO
#
# Campo obrigatório para quem não é casado. Vive em união estável?
#
# Sim
#
# Não
#
# ## Forma de Recebimento
#
# Conta Corrente Bradesco
#
# TED
#
# Banco BRADESCO
#
# Agência
#
# Dígito
#
# Conta
#
# Dígito
#
# 1066
#
# 1524
#
# 5
#
# ## Dados do(s) 20 Vendedor(es) Pessoa Física/Pessoa Jurídica
#
# Nome Completo Razão Social (sem abreviaçães)
#
# CPFICNPJIMF
#
# Profissão
#
# E-mail
#
# Estado Civil
#
# Campo obrigatório para quem não é casado. Vive em união estável?
#
# Sim
#
# Não
#
# ## Forma de Recebimento
#
# Conta Corrente Bradesco
#
# TED
#
# Banco
#
# Agência
#
# Dígito
#
# Conta
#
# Dígito
#
# ## Dados do Imóvel a ser Financiado
#
# Endereço
#
# Número
#
# Complemento
#
# ARSO 24 CONDOMINIO ALPHAVILLE PALMAS 2, RUA 09
#
# QD C2, LOTE 31
#
# Quantidade de Vagas
#
# No de Vagas
#
# [Quantidade Depósito Box
#
# No Depósito Box
#
# <!-- image -->
#
# ## Condiçôes da Operação (todos os itens deste bloco são de preenchimento obrigatório)
#
# Valor da Compra/Venda
#
# Valor de Financiamento
#
# R$ 2.600.000,00
#
# RS 1.800.000,00
#
# Irá utilizar 0 FGTS
#
# [Prazo de Amortização
#
# Sim Não
#
# 420 MESES
#
# Dia base para pagamento das prestaçoes (De 01 a 28)
#
# 30 DIAS APÓS ASSINATURA DO CONTRATO
#
# ## Sistema de Amortização:
#
# SAC Sistema de Amortização Constante
#
# Tabela PRICE
#
# Deseja incluir as despesas cartorárias no financiamento
#
# Sim
#
# Não
#
# #Valor do financiamento das despesas cartorárias é limitado a 5% do valor de compra e venda do imóvel e será liberado no ato da assinatura do contrato.
#
# ## Aceite Registro Eletrônico (Assinatura Digital)
#
# O(s) Comprador(es) aceita(m) a de realizar(em) a(s) assinatura(s) e 0 registro do contrato em formato digital no Serviço de Registro de Imóveis, nos termos da MP 2.200-2/2001, art. 10, $ 10. opção
#
# Sim
#
# Não
#
# - Optando por esse formato, o(s)   Comprador(es) e Vendedor(es)   precisarão   preencher formulário 4840-1217 Declaração das Partes Aceite Registro Eletrônico (Assinatura Digital). Opção não disponível para operaçães com "Interveniente Quitante" (quando outro banco tem que conceder quitação no contrato)
#
# ## Informaçães Adicionais (se assim aplicável)
#
# Processo sendo conduzido por Parceiro Imobiliário do Bradesco? Se sim favor informar
#
# Nome
#
# CNPJIMF
#
# ## Declaraçães do (s) Comprador (es)
#
# O(s) Comprador(es) declara(m) que:
#
# - (i) no caso de irregularidades nos documentos relativos ao imóvel e ao(s) Vendedor(es), a concessão do a utilização do FGTS poderá(ão) ser negada(s) ou poderão ser solicitados outros documentos para esclarecimento;
# - (ii) obteve previamente do(s) Vendedor(es) informaçães sobre os documentos e certidães do imóvel e, em artigo 10 da Lei no 7.433/85 e a obtenção da Certidão Negativas de Débitos Trabalhistas CNDT, nos termos do artigo 642-A da CLT, ciente(s) da possibilidade de obtenção prévia; gratuita e eletrônica da referida CNDT, isentando 0 Bradesco de qualquer responsabilidade. O(s) Comprador(es) concorda(m) com a
#
# ## dispensa?
#
# Sim
#
# Não
#
# ## E com as dispensas abaixo?
#
# Declaração de inexistência de débitos condominiais:
#
# Sim
#
# Não
#
# Certidão Negativa de Impostos e Taxas Municipais:
#
# Sim
#
# Não
#
# Declaração de regularidade de foro (para imóveis foreiros):
#
# Sim
#
# Não
#
# Em caso de exigências do Serviço de Registro de Imóveis da comarca do imóvel, os documentos acima não poderão ser dispensados.
#
# (iii) em caso de cancelamento do contrato; os valores creditados em favor do(s)   Comprador(es) para financiamento do ITBI (Imposto de Transmissão de Bens Imóveis) e pagamento das despesas cartorárias deverão ser devolvidos ao Banco Bradesco S.A , mediante débito na conta-corrente que o(s) Comprador(es)  desde já, autoriza 0 Bradesco a realizar . Se 0 saldo não for suficiente para a realização
#
# <!-- image -->
#
# do débito, 0 débito   poderá recair sobre eventuais limites de crédito mantidos na conta   do(s) Comprador(es) informada neste documento; se contratados, inclusive por meio de lançamento parcial; (iv) que está(ão) ciente(s) e concorda(m) que 0 Banco Bradesco SA. não se compromete com a aprovação do financiamento e também não será   responsável por qualquer   importância paga anteriormente, a qualquer título; ao Vendedor(es); por eventuais multas e despesas com a rescisão do Instrumento Particular de Compromisso de Compra e Venda do imóvel firmado com 0(s) Vendedor(es) e; pelos prazos fixados com 0(s) Vendedor(es) para pagamento do preço de compra e venda; entrega das chaves do imóvel e recebimento de ITBI ou Laudêmio.
#
# - (v) para as operaçães de financiamento residencial POUPANÇA MAIS , a taxa de juros é flutuante, rendimento será calculado conforme a Lei no 12.703/2012 e a TR (Taxa Referencial) atualizará 0 saldo devedor das operaçães, sendo que 0(s) Comprador(es) foi(ram) suficientemente informado(a,s) que neste tipo de indexador existe a imprevisibilidade do valor das prestaçães, em razão da variação da remuneração da poupança, fazendo com que exista a possibilidade de incidir sobre a operação taxa de juros superior à contratada inicialmente, tendo como consequência; 0 aumento do valor da prestação:
#
# ## Importante
#
# Para compradores casados sob 0 regime de separação total de bens, indicar por declaração adicional respectivos  percentuais de aquisição do imóvel. Caso não seja declarado ou 0 regime seja 0 da comunhão parcial ou universal de bens será considerado automaticamente percentual de 509 do imóvel para cada um:
#
# - 0 Bradesco declara que cumpre toda a legislação aplicável sobre segurança da informação; privacidade e proteção de dados, em observância a Lei Geral de Proteção de Dados (Lei Federal no 13.709/2018) e demais normas setoriais ou gerais sobre 0 tema, comprometendo-se a tratar os dados pessoais coletados por meio deste instrumento para a sua execução e somente nos estritos limites e finalidades aqui previstos; como controlador de dados pessoais ou por meio de seus operadores; nos termos da lei aplicável.
#
# Local PALMAS
#
# Data 16/10/2024
#
# 70 Comprador
#
# 20 Comprador
#
# NAGYLA POLLYANNA FERREIRA CRUZ
#
# EDER CARLOS MANDOTTI
#
# 30 Comprador
#
# 40 Comprador
#
# Fone Fácil Bradesco Consultas, Informaçães e Serviços Transacionais. Capitais e Regiães Metropolitanas: 4002 0022 Demais Localidades: 0800 570 0022 Atendimento 24 horas, 7 dias por semana:
#
# SAC Alô Bradesco: 0800 704 8383 Deficiência Auditiva ou de Fala: 0800 722 0099 Reclamaçães, Cancelamentos e Informaçães Gerais. Atendimento 24 horas, 7 dias por semana.
#
# Ouvidoria: 0800 727 9933 Se não ficar satisfeito com a solução apresentada, contate a Ouvidoria, das 09h às 18h, de 2a a 6a feira, exceto feriados.

# %%
import pandas as pd

pd.set_option('display.max_rows', df.shape[0]+1)

# %%
csv_path = "data/textract/keyValues.csv"

# %%
df = pd.read_csv(csv_path)
df.drop(columns=["'Page number","'Confidence Score % (Key)", "'Confidence Score % (Value)"], inplace=True)
df.to_excel("extraction.xlsx")
